# %% [markdown]
# ## Dictionaries
#
# If you can only know one data structure, this is the one to know.

# %%
phone = { 'Jenni':8675309, 'Emergency':911}

# %%
phone['Jenni']
# Out:
# 8675309

# %%
phone['Fred']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_107/3234263447.py in <module>
# ----> 1 phone['Fred']
#
# KeyError: 'Fred'

# %%
'Fred' in phone
# Out:
# False

# %%
'Jenni' in phone
# Out:
# True

# %%
phone['Fred'] = 5551234

# %%
phone['Fred']
# Out:
# 5551234

# %%
phone
# Out:
# {'Jenni': 8675309, 'Emergency': 911, 'Fred': 5551234}

# %%
phone.keys()
# Out:
# dict_keys(['Jenni', 'Emergency', 'Fred'])

# %%
phone.keys()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_107/23850742.py in <module>
# ----> 1 phone.keys()[0]
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
list(phone.keys())[0]
# Out:
# 'Jenni'

# %%
phone.values()
# Out:
# dict_values([8675309, 911, 5551234])

# %%
for i in phone.keys():
    print(i,'phone number is', phone[i])
# Out:
# Jenni phone number is 8675309
# Emergency phone number is 911
# Fred phone number is 5551234

# %%
s = {2,3,5,7}

# %%
len(s)
# Out:
# 4

# %%
s.intersection({3,5,9})
# Out:
# {3, 5}

# %%
def inc(x):
    return x + 1

# %%
set(map(inc,s))
# Out:
# {3, 4, 6, 8}

# %%
friends = {}

# %%
friends['Sue'] = 'James'

# %%
friends
# Out:
# {'Sue': 'James'}

# %%
8 in s
# Out:
# False
