# %%
import seaborn as sns

# %%
ans = sns.load_dataset('anscombe')

# %%
ans.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.lmplot(data=ans,x='x',y='y',hue='dataset')
