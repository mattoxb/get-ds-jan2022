# %%
import seaborn as sns
import pandas as pd

# %%
insd = pd.read_csv('insurance.csv')

# %%
insd.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
len(insd)
# Out:
# 1338

# %%
sns.displot(data=insd,x='age',y='charges')

# %%
sns.lmplot(data=insd,x='age',y='charges')

# %%
sns.lmplot(data=insd,x='bmi',y='charges',hue='children')

# %%
sns.lmplot(data=insd,x='bmi',y='charges',hue='smoker')

# %%
sns.swarmplot(data=insd,y='charges',x='smoker',hue='smoker')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
